# %%
import os

import pandas as pd
from sqlalchemy import create_engine, text

# %%
# Example database URLs:
#
# PostgreSQL:
# postgresql+psycopg2://username:password@localhost:5432/database_name
DATABASE_URL = 'postgresql+psycopg2://postgres:;|-p,8y"e&OgPY8n@34.60.16.16:5432/feature-service-db'

if not DATABASE_URL:
    raise ValueError("Set the DATABASE_URL environment variable.")

# Create the database connection pool.
engine = create_engine(
    DATABASE_URL,
    pool_pre_ping=True,
)

query = text(f"""
    SELECT * FROM public.energy_timeseries
    ORDER BY iso_code DESC, interval_start_utc DESC, interval_end_utc DESC LIMIT 100
""")

try:
    with engine.connect() as connection:
        df = pd.read_sql_query(
            sql=query,
            con=connection,
        )

    print(f"Loaded {len(df):,} rows.")
    print(df)

except Exception as exc:
    print(f"Database query failed: {exc}")
    raise

finally:
    engine.dispose()
# Out:
# Loaded 100 rows.
#    iso_code        interval_start_utc          interval_end_utc     load_mw  \
# 0       SPP 2026-08-04 04:55:00+00:00 2026-08-04 05:00:00+00:00  41569.0000
# 1       SPP 2026-08-03 04:55:00+00:00 2026-08-03 05:00:00+00:00  39590.0000
# 2       SPP 2026-08-02 04:55:00+00:00 2026-08-02 05:00:00+00:00  37735.0000
# 3       SPP 2026-08-01 04:55:00+00:00 2026-08-01 05:00:00+00:00  41001.0000
# 4       SPP 2026-07-31 04:55:00+00:00 2026-07-31 05:00:00+00:00  44053.0000
# ..      ...                       ...                       ...         ...
# 95    NYISO 2026-08-04 16:35:00+00:00 2026-08-04 16:35:00+00:00  19120.6856
# 96    NYISO 2026-08-04 16:30:00+00:00 2026-08-04 16:30:00+00:00  19083.1862
# 97    NYISO 2026-08-04 16:25:00+00:00 2026-08-04 16:25:00+00:00  19030.5689
# 98    NYISO 2026-08-04 16:20:00+00:00 2026-08-04 16:20:00+00:00  18994.4828
# 99    NYISO 2026-08-04 16:15:00+00:00 2026-08-04 16:15:00+00:00  18988.6911
#
# ...
